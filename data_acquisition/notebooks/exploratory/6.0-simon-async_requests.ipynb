# %% [markdown]
# # try `requests-futures` for async requests
#
# The code is [here](https://github.com/ross/requests-futures).

# %%
! pip install requests-futures
# Out:
# Requirement already satisfied: requests-futures in /anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: requests>=1.2.0 in /anaconda3/lib/python3.6/site-packages (from requests-futures)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.6/site-packages (from requests>=1.2.0->requests-futures)
# Requirement already satisfied: idna<2.7,>=2.5 in /anaconda3/lib/python3.6/site-packages (from requests>=1.2.0->requests-futures)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /anaconda3/lib/python3.6/site-packages (from requests>=1.2.0->requests-futures)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.6/site-packages (from requests>=1.2.0->requests-futures)
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ## benchmarks
#
# Good news:
# - with 1 worker, 10 requests takes ~10X faster than 1 request
# - with 5 workers, 10 requests takes ~2X faster than 1 request
# - for 1 request, 1 worker is about as fast as 5 workers
#
# http://httpbin.org/get is used in the `requests-futures` examples.

# %%
from concurrent.futures import ThreadPoolExecutor
from requests_futures.sessions import FuturesSession


def get_httpbin_contents(session, n_requests):
    # gather futures
    futures = []
    for i in range(n_requests):
        url = 'http://httpbin.org/get?foo={}'.format(i)
        futures.append(session.get(url))
    # wait for responses, get the contents
    contents = []
    for f in futures:
        response = f.result()
        if response.status_code == 200:
            contents.append(response.content)
        else:
            raise Exception(response)
    return contents


session_1 = FuturesSession(max_workers=1)
session_5 = FuturesSession(max_workers=5)

# %%
contents = get_httpbin_contents(session_1, 1)
print(eval(contents[0]))
# Out:
# {'args': {'foo': '0'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Connection': 'close', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.18.4'}, 'origin': '12.31.132.194', 'url': 'http://httpbin.org/get?foo=0'}

# %%
# %%timeit
# 1 worker, 1 request
get_httpbin_contents(session_1, 1)
# Out:
# 109 ms ± 7.26 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
# 1 worker, 10 requests
get_httpbin_contents(session_1, 10)
# Out:
# 1.05 s ± 160 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
# 5 workers, 1 request
get_httpbin_contents(session_5, 1)
# Out:
# 98.7 ms ± 6.5 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
# 5 workers, 10 requests
get_httpbin_contents(session_5, 10)
# Out:
# 231 ms ± 29.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## more sophisticated requests
#
# good news:
# - `requests-futures` can do anything `requests` can do
#
# bad news:
# - `requests-futures` is poorly documented

# %%
help(session_1.get)
type(session_1.get('http://httpbin.org/get'))
# Out:
# Help on method get in module requests.sessions:
#
# get(url, **kwargs) method of requests_futures.sessions.FuturesSession instance
#     Sends a GET request. Returns :class:`Response` object.
#
#     :param url: URL for the new :class:`Request` object.
#     :param \*\*kwargs: Optional arguments that ``request`` takes.
#     :rtype: requests.Response
# concurrent.futures._base.Future

# %%
import os
from dotenv import load_dotenv

exploratory_directory = os.getcwd()
notebooks_directory = os.path.abspath(os.path.join(exploratory_directory, os.pardir))
experiment_directory = os.path.abspath(os.path.join(notebooks_directory, os.pardir))

dotenv_path = os.path.join(experiment_directory, '.env')
load_dotenv(dotenv_path)

YELP_API_KEY = os.environ.get('YELP_API_KEY')
API_HOST = os.environ.get('API_HOST')
SEARCH_PATH = os.environ.get('SEARCH_PATH')

# %%
# import os
# import json
import requests

from urllib.error import HTTPError
from urllib.parse import quote
from urllib.parse import urlencode


lat, lng = 41.88, -87.63
radius = 100
categories = ['zoos', 'beaches', 'restaurants']

url_params = {
    'categories': '+'.join(categories),
    'latitude': lat,
    'longitude': lng,
    'radius': radius,
    'limit': 50
}

url = '{0}{1}'.format(API_HOST, quote(SEARCH_PATH.encode('utf8')))
headers = {
    'Authorization': 'Bearer %s' % YELP_API_KEY,
}

response = requests.request('GET', url, headers=headers, params=url_params)
rj_1 = response.json()
rj_1['businesses'][0]
# Out:
# {'id': '4wmRu3bpaSpW999SHGK34g',
#  'alias': 'revival-food-hall-chicago',
#  'name': 'Revival Food Hall',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jTYJnk7AnRd-zNjoDUcrDQ/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/revival-food-hall-chicago?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#  'review_count': 300,
#  'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#  'rating': 4.0,
#  'coordinates': {'latitude': 41.87979, 'longitude': -87.63051},
#  'transactions': ['pickup', 'delivery'],
#  'price': '$$',
#  'location': {'address1': '125 S Clark St',
#   'address2': '',
#   'address3': None,
#   'city': 'Chicago',
#   'zip_code': '60603',
#   'country': 'US',
#   'state': 'IL',
#   'display_address': ['125 S Clark St', 'Chicago, IL 60603']},
#  'phone': '+17739999411',
#  'display_phone': '(773) 999-9411',
#  'distance': 37.54272999315398}

# %%
future = session_1.get(url, headers=headers, params=url_params)
response = future.result()
rj_2 = response.json()
rj_2['businesses'][0]
# Out:
# {'id': '4wmRu3bpaSpW999SHGK34g',
#  'alias': 'revival-food-hall-chicago',
#  'name': 'Revival Food Hall',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jTYJnk7AnRd-zNjoDUcrDQ/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/revival-food-hall-chicago?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#  'review_count': 300,
#  'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#  'rating': 4.0,
#  'coordinates': {'latitude': 41.87979, 'longitude': -87.63051},
#  'transactions': ['delivery', 'pickup'],
#  'price': '$$',
#  'location': {'address1': '125 S Clark St',
#   'address2': '',
#   'address3': None,
#   'city': 'Chicago',
#   'zip_code': '60603',
#   'country': 'US',
#   'state': 'IL',
#   'display_address': ['125 S Clark St', 'Chicago, IL 60603']},
#  'phone': '+17739999411',
#  'display_phone': '(773) 999-9411',
#  'distance': 37.54272999315398}

# %%
def _submit_request(future_session, url, headers, parameters):
    categories = parameters['response']['categories']
    lat = parameters['response']['circle']['center']['lat']
    lng = parameters['response']['circle']['center']['lng']
    radius = parameters['response']['circle']['radius']
    url_params = {
        'categories': '+'.join(categories),
        'latitude': lat,
        'longitude': lng,
        'radius': radius,
        'limit': 50 #TODO paginate
    }
    return future_session.get(url, headers=headers, params=url_params)


def make_async_requests(future_session, parameter_lists, API_HOST,
                        SEARCH_PATH, YELP_API_KEY):
    url = '{0}{1}'.format(API_HOST, quote(SEARCH_PATH.encode('utf8')))
    headers = {'Authorization': 'Bearer %s' % YELP_API_KEY}
    # submit async requests
    futures = []
    for parameters in parameter_lists:
        f = _submit_request(future_session, url, headers, parameters)
        futures.append(f)
    # wait for responses, get the contents and record errors
    contents = []
    errors_responses = []
    for f in futures:
        response = f.result()
        if response.status_code == 200:
            contents.append(response.json())
        else:
            errors_responses.append(response)
    return contents, errors_responses

# %%
circle = {'center': {'lat': lat, 'lng': lng}, 'radius': radius}
parameters = {'response': {'circle': circle, 'categories': categories}}
parameter_lists = [parameters]

contents, errors_responses = make_async_requests(
    session_1, parameter_lists, API_HOST, SEARCH_PATH, YELP_API_KEY
)

contents[0]['businesses']
# Out:
# [{'id': '4wmRu3bpaSpW999SHGK34g',
#   'alias': 'revival-food-hall-chicago',
#   'name': 'Revival Food Hall',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jTYJnk7AnRd-zNjoDUcrDQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/revival-food-hall-chicago?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 300,
#   'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.87979, 'longitude': -87.63051},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '125 S Clark St',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['125 S Clark St', 'Chicago, IL 60603']},
#   'phone': '+17739999411',
#   'display_phone': '(773) 999-9411',
#   'distance': 37.54272999315398},
#  {'id': 'IRa05qXL2uU_WotrRgWNiQ',
#   'alias': 'the-marq-chicago-2',
#   'name': 'The Marq',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QmSKppis1tENPPJsVgzx7A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-marq-chicago-2?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 427,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8796191, 'longitude': -87.6299253},
#   'transactions': ['pickup', 'restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '60 West Adams St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['60 West Adams St', 'Chicago, IL 60603']},
#   'phone': '+13126004434',
#   'display_phone': '(312) 600-4434',
#   'distance': 42.80323071239753},
#  {'id': 'lD3qc5CidZj1yRi1p0xl6g',
#   'alias': 'the-fat-shallot-chicago-5',
#   'name': 'The Fat Shallot',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VkHhGDYnhFcAvXmGqjPOFQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-fat-shallot-chicago-5?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 166,
#   'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'catering', 'title': 'Caterers'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.8797006295987,
#    'longitude': -87.6302485220684},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '77 W Adams',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['77 W Adams', 'Chicago, IL 60603']},
#   'phone': '+17738930826',
#   'display_phone': '(773) 893-0826',
#   'distance': 39.133783700913554},
#  {'id': '4hEWyzVZ4gKdAoBpsd7Rrw',
#   'alias': 'the-italian-village-restaurants-chicago',
#   'name': 'The Italian Village Restaurants',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Run-GPxG95c5XhfKnnnwEQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-italian-village-restaurants-chicago?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 792,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.88034, 'longitude': -87.63016},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '71 W Monroe St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['71 W Monroe St', 'Chicago, IL 60603']},
#   'phone': '+13123327005',
#   'display_phone': '(312) 332-7005',
#   'distance': 62.24588988937359},
#  {'id': 'VkVIa1KvViXWJU0MdlCIhA',
#   'alias': 'zoup-chicago',
#   'name': 'Zoup!',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Hf_yf5QfHf-G6SQ9I8I5cA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/zoup-chicago?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 113,
#   'categories': [{'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'soup', 'title': 'Soup'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8795639, 'longitude': -87.6301255},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '62 W Adams St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['62 W Adams St', 'Chicago, IL 60603']},
#   'phone': '+13124709797',
#   'display_phone': '(312) 470-9797',
#   'distance': 43.30325842248242},
#  {'id': 'NRY7NmPVGMSfWealHdmcYw',
#   'alias': 'farmers-fridge-chicago-13',
#   'name': "Farmer's Fridge",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ErwWzi7Ba-ZwdXMcHrlxfQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/farmers-fridge-chicago-13?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 74,
#   'categories': [{'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'gourmet', 'title': 'Specialty Food'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8797547287141,
#    'longitude': -87.6304800899465},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '108 N State',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60602',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['108 N State', 'Chicago, IL 60602']},
#   'phone': '+13122290099',
#   'display_phone': '(312) 229-0099',
#   'distance': 48.203664519395},
#  {'id': 'kTdNYKe1YcTl9c1Y2itUhA',
#   'alias': 'brown-bag-seafood-chicago-2',
#   'name': 'Brown Bag Seafood',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UAWvMecrphDbbJgQOyZhmg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/brown-bag-seafood-chicago-2?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 77,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.87979, 'longitude': -87.63051},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '125 South Clark',
#    'address2': '',
#    'address3': 'Revival Food Hall',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['125 South Clark',
#     'Revival Food Hall',
#     'Chicago, IL 60603']},
#   'phone': '+17737706173',
#   'display_phone': '(773) 770-6173',
#   'distance': 52.834621661642785},
#  {'id': '7a9BG-eTJahBhyhqKqba5w',
#   'alias': 'vivere-chicago',
#   'name': 'Vivere',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/k2J3kkM_j8CocHCGFlnctQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/vivere-chicago?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 121,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.8803520202637,
#    'longitude': -87.6301345825195},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '71 W Monroe St',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['71 W Monroe St', 'Chicago, IL 60603']},
#   'phone': '+13123327005',
#   'display_phone': '(312) 332-7005',
#   'distance': 62.202808381640665},
#  {'id': 'D0BKmF373uEMzVN8up9wAg',
#   'alias': 'potbelly-sandwich-shop-chicago-7',
#   'name': 'Potbelly Sandwich Shop',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_b5rLyWnEoc3G3FtmsbYFQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/potbelly-sandwich-shop-chicago-7?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 56,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.880267, 'longitude': -87.62962},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '55 W Monroe St',
#    'address2': 'Lbby 100D',
#    'address3': 'Space 100D',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['55 W Monroe St',
#     'Lbby 100D',
#     'Space 100D',
#     'Chicago, IL 60603']},
#   'phone': '+13125770070',
#   'display_phone': '(312) 577-0070',
#   'distance': 43.25696908711414},
#  {'id': 'lce1pN2zQsEoOnV-WI-E2Q',
#   'alias': 'argo-tea-chicago-8',
#   'name': 'Argo Tea',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_0OmP2z4bb3mO7dwDRNTSw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/argo-tea-chicago-8?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 68,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.87979, 'longitude': -87.62974},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '140 S Dearborn St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['140 S Dearborn St', 'Chicago, IL 60603']},
#   'phone': '+17736634471',
#   'display_phone': '(773) 663-4471',
#   'distance': 33.19421367437768},
#  {'id': '0wjsaNjinNu2rcKz1JpnKQ',
#   'alias': 'furious-spoon-revival-food-hall-chicago',
#   'name': 'Furious Spoon - Revival Food Hall',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-i8nAzNj4dqJhez1MnNr1g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/furious-spoon-revival-food-hall-chicago?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 145,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.8799369, 'longitude': -87.6306651},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '125 S Clark St',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['125 S Clark St', 'Chicago, IL 60603']},
#   'phone': '+17737706125',
#   'display_phone': '(773) 770-6125',
#   'distance': 52.834621661642785},
#  {'id': 'N0b2FoV_dJIPNtMkRgffJA',
#   'alias': 'pret-a-manger-chicago-3',
#   'name': 'Pret A Manger',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MddcvSEQqyn9lqWOOojTJg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pret-a-manger-chicago-3?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 87,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.88033, 'longitude': -87.63028},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '73 West Monroe',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['73 West Monroe', 'Chicago, IL 60603']},
#   'phone': '+13122604301',
#   'display_phone': '(312) 260-4301',
#   'distance': 45.37471822376514},
#  {'id': 'E4viDrgaOn_0yTtPYOYw1Q',
#   'alias': 'the-budlong-revival-food-hall-chicago',
#   'name': 'The Budlong - Revival Food Hall',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qJzFEx1tEDN5XGkz0ndNSQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-budlong-revival-food-hall-chicago?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 73,
#   'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'},
#    {'alias': 'foodstands', 'title': 'Food Stands'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8799369, 'longitude': -87.6306651},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '125 S Clark St',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['125 S Clark St', 'Chicago, IL 60603']},
#   'phone': '+17732709005',
#   'display_phone': '(773) 270-9005',
#   'distance': 52.834621661642785},
#  {'id': 'GRXA9MpYRfFKRk2_3eJMRQ',
#   'alias': 'antique-taco-chiquito-chicago',
#   'name': 'Antique Taco Chiquito',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/a9TM4QMxjUGnRH822hs4Cg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/antique-taco-chiquito-chicago?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 27,
#   'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#    {'alias': 'foodstands', 'title': 'Food Stands'},
#    {'alias': 'catering', 'title': 'Caterers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.87979, 'longitude': -87.63051},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '125 South Clark St',
#    'address2': None,
#    'address3': 'Revival Food Hall',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['125 South Clark St',
#     'Revival Food Hall',
#     'Chicago, IL 60603']},
#   'phone': '+17737706195',
#   'display_phone': '(773) 770-6195',
#   'distance': 34.88119506520243},
#  {'id': 'JLTa7JFqkfv5LRKvELSCdg',
#   'alias': 'the-fat-shallot-chicago-6',
#   'name': 'The Fat Shallot',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uiM20Yr_KX-gc09WUEYO_w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-fat-shallot-chicago-6?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 11,
#   'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#    {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.879552, 'longitude': -87.630116},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '77 W. Adams St.',
#    'address2': '',
#    'address3': 'Revival Food Hall',
#    'city': 'Chicago',
#    'zip_code': '60601',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['77 W. Adams St.',
#     'Revival Food Hall',
#     'Chicago, IL 60601']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 50.73254113573074},
#  {'id': 'Ve6qGCqpPxsgPf8VWwNDgQ',
#   'alias': 'union-squared-chicago',
#   'name': 'Union Squared',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/n9IfnNZlOJ0folSUxn5JPA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/union-squared-chicago?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 28,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8799369, 'longitude': -87.6306651},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '125 S Clark St',
#    'address2': '',
#    'address3': 'Revival Food Hall',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['125 S Clark St',
#     'Revival Food Hall',
#     'Chicago, IL 60603']},
#   'phone': '+17737706168',
#   'display_phone': '(773) 770-6168',
#   'distance': 37.54272999315398},
#  {'id': 'ISkVsSLvprNwiZHfku6F_A',
#   'alias': 'dollop-coffee-chicago-4',
#   'name': 'Dollop Coffee',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HpQ1p_KATMEOkoSuvYYzUA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dollop-coffee-chicago-4?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 35,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.88036, 'longitude': -87.6298},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '55 W Monroe St',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['55 W Monroe St', 'Chicago, IL 60603']},
#   'phone': '+13123741854',
#   'display_phone': '(312) 374-1854',
#   'distance': 45.39487147127008},
#  {'id': 'nPVD4LB1lEiSm9O-ygHMFA',
#   'alias': 'corner-bakery-cafe-chicago-36',
#   'name': 'Corner Bakery Cafe',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hlrnkc0xmuj0KXF37hfAbQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/corner-bakery-cafe-chicago-36?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 48,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 41.87979, 'longitude': -87.62974},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '140 S Dearborn St',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['140 S Dearborn St', 'Chicago, IL 60603']},
#   'phone': '+13129209100',
#   'display_phone': '(312) 920-9100',
#   'distance': 43.39720479785765},
#  {'id': 'Sy8W9dOTHoBdECNV4VcaBw',
#   'alias': 'revival-cafe-bar-chicago-2',
#   'name': 'Revival Cafe Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8fP0vo-nXQ-fF3JxG1sTSA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/revival-cafe-bar-chicago-2?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 17,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8799369, 'longitude': -87.6306651},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '125 S Clark St',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['125 S Clark St', 'Chicago, IL 60603']},
#   'phone': '+17739999411',
#   'display_phone': '(773) 999-9411',
#   'distance': 37.54272999315398},
#  {'id': 'N7izDmbDyLa96gT6yQDhHA',
#   'alias': 'specialtys-café-and-bakery-chicago-7',
#   'name': "Specialty's Café & Bakery",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/G30EwRMnTSwWNoH_Q34haA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/specialtys-caf%C3%A9-and-bakery-chicago-7?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 79,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.8809246, 'longitude': -87.6292451},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '77 South Dearborn St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['77 South Dearborn St', 'Chicago, IL 60603']},
#   'phone': '+18775022837',
#   'display_phone': '(877) 502-2837',
#   'distance': 137.66381956662184},
#  {'id': '4-NmeBHa9QItskOcW945EA',
#   'alias': 'noodles-and-company-chicago-11',
#   'name': 'Noodles & Company',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2q5_cdnQiEqIh5Zds4yMPw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/noodles-and-company-chicago-11?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 74,
#   'categories': [{'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 41.8813733, 'longitude': -87.6306805},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '47 S Clark St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['47 S Clark St', 'Chicago, IL 60603']},
#   'phone': '+13122631927',
#   'display_phone': '(312) 263-1927',
#   'distance': 130.8674558932524},
#  {'id': 'vEr2Zi-dkDbpI0OzNemTew',
#   'alias': 'la-cantina-chicago',
#   'name': 'La Cantina',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Mm6-KSQidlaT5EJcy7AmGA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-cantina-chicago?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 53,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'diners', 'title': 'Diners'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 41.8803520202637,
#    'longitude': -87.6301345825195},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '71 W Monroe St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['71 W Monroe St', 'Chicago, IL 60603']},
#   'phone': '+13123327005',
#   'display_phone': '(312) 332-7005',
#   'distance': 62.202808381640665},
#  {'id': '3jxmuI_A7Vayb-98I3-Y7w',
#   'alias': 'danke-chicago',
#   'name': 'Danke',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FXVSI2BoNl1IwUWONRpdIw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/danke-chicago?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 17,
#   'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.87979, 'longitude': -87.63051},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '125 S Clark St',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['125 S Clark St', 'Chicago, IL 60603']},
#   'phone': '+17737706125',
#   'display_phone': '(773) 770-6125',
#   'distance': 37.54272999315398},
#  {'id': 'oeqo_YONXZuRBeyC419fww',
#   'alias': 'mcdonalds-chicago-22',
#   'name': "McDonald's",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vzGPrkgb3ONmE8mhdR-tEw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mcdonalds-chicago-22?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 31,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 41.880939, 'longitude': -87.6305628},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '23 S Clark',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['23 S Clark', 'Chicago, IL 60603']},
#   'phone': '+13125800214',
#   'display_phone': '(312) 580-0214',
#   'distance': 114.33639478774735},
#  {'id': 'I-vTtwc_rqCW10Ya_L4okw',
#   'alias': 'farmers-fridge-chicago-14',
#   'name': "Farmer's Fridge",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/J6FZM_Jrw3f6K1g00ZOfNg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/farmers-fridge-chicago-14?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 13,
#   'categories': [{'alias': 'salad', 'title': 'Salad'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 41.87979, 'longitude': -87.63051},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '125 S Clark',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['125 S Clark', 'Chicago, IL 60603']},
#   'phone': '+13122290099',
#   'display_phone': '(312) 229-0099',
#   'distance': 37.54272999315398},
#  {'id': 'IHhesEYlrNKqtfKW0SAznA',
#   'alias': 'marquette-building-chicago',
#   'name': 'Marquette Building',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0v-TgMZWrhuRB_evzP1Hbw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/marquette-building-chicago?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 4,
#   'categories': [{'alias': 'landmarks',
#     'title': 'Landmarks & Historical Buildings'},
#    {'alias': 'architecturaltours', 'title': 'Architectural Tours'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.87979, 'longitude': -87.62974},
#   'transactions': [],
#   'location': {'address1': '140 S Dearborn St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['140 S Dearborn St', 'Chicago, IL 60603']},
#   'phone': '+13124225500',
#   'display_phone': '(312) 422-5500',
#   'distance': 43.39720479785765},
#  {'id': '8DFC6CcYWnqbqWiZMaT1vA',
#   'alias': 'the-flamingo-by-alexander-calder-chicago',
#   'name': 'The Flamingo By Alexander Calder',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EikLfYMK81TzCtP-8yy4Dw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-flamingo-by-alexander-calder-chicago?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 2,
#   'categories': [{'alias': 'publicart', 'title': 'Public Art'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 41.8795828, 'longitude': -87.6295635},
#   'transactions': [],
#   'location': {'address1': '50 W Adams St',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60610',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['50 W Adams St', 'Chicago, IL 60610']},
#   'phone': '+13127442400',
#   'display_phone': '(312) 744-2400',
#   'distance': 60.30256525314967},
#  {'id': 'q0dy950BiJEWOGEeIm7QSQ',
#   'alias': 'chagalls-four-seasons-chicago',
#   'name': "Chagall's Four Seasons",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bNdVH1Rgrg9J4CX8HPwVjw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chagalls-four-seasons-chicago?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 5,
#   'categories': [{'alias': 'publicart', 'title': 'Public Art'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.8810667508273,
#    'longitude': -87.6297620032496},
#   'transactions': [],
#   'location': {'address1': '10 S Dearborn St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['10 S Dearborn St', 'Chicago, IL 60603']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 120.24248193726142},
#  {'id': 'm_y-h3e07jkFZr0Ztbcwkw',
#   'alias': 'black-fodder-coffee-chicago-6',
#   'name': 'Black Fodder Coffee',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lTphIWx1igQv4-WA2hnrZQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/black-fodder-coffee-chicago-6?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 1,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 41.88033, 'longitude': -87.63028},
#   'transactions': [],
#   'location': {'address1': '73 W Monroe St',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['73 W Monroe St', 'Chicago, IL 60603']},
#   'phone': '+13122483575',
#   'display_phone': '(312) 248-3575',
#   'distance': 45.37471822376514},
#  {'id': 'RSsNYHnDvPx1gJ3wi2V8dg',
#   'alias': 'smoque-chicago-3',
#   'name': 'Smoque',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/smoque-chicago-3?adjust_creative=y27hFOR4ZHFRcL4Kq4aq9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y27hFOR4ZHFRcL4Kq4aq9w',
#   'review_count': 2,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 41.8795683950925,
#    'longitude': -87.6304205413995},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '125 S Clark St',
#    'address2': 'Revival Food Hall',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['125 S Clark St',
#     'Revival Food Hall',
#     'Chicago, IL 60603']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 59.29117954981982}]
